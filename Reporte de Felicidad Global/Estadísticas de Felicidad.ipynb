# %% [markdown]
# # Felicidad

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import seaborn as sb

# %%
#Carga de archivos
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('Archivo cargado "{name}" '.format(name=fn))
# Out:
#      <input type="file" id="files-45c86de3-a129-4bcc-b30c-1cb777de58e9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-45c86de3-a129-4bcc-b30c-1cb777de58e9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2015.csv to 2015.csv
# Saving 2016.csv to 2016.csv
# Saving 2017.csv to 2017.csv
# Saving 2018.csv to 2018.csv
# Saving 2019.csv to 2019.csv
# Archivo cargado "2015.csv"
# Archivo cargado "2016.csv"
# Archivo cargado "2017.csv"
# Archivo cargado "2018.csv"
# Archivo cargado "2019.csv"

# %%
data2019 = pd.read_csv("2019.csv")
data2018 = pd.read_csv("2018.csv")
data2017 = pd.read_csv("2017.csv")
data2016 = pd.read_csv("2016.csv")
data2015 = pd.read_csv("2015.csv")

# %%
data2019.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %%
data2019.columns.values
# Out:
# array(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'], dtype=object)

# %%
data2017.columns.values
# Out:
# array(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'], dtype=object)

# %%
data2017.rename(columns={'Country': 'Country or region', 'Happiness.Rank': 'Overall rank', 'Happiness.Score': 'Score', 
                         'Economy..GDP.per.Capita.': 'GDP per capita', 'Family': 'Social support', 'Freedom': 'Freedom to make life choices',
                         'Trust..Government.Corruption.': 'Perceptions of corruption', 'Health..Life.Expectancy.': 'Healthy life expectancy'}, inplace=True)

# %%
data2017.head()
# Out:
#   Country or region  Overall rank  ...  Perceptions of corruption  Dystopia.Residual
# 0            Norway             1  ...                   0.315964           2.277027
# 1           Denmark             2  ...                   0.400770           2.313707
# 2           Iceland             3  ...                   0.153527           2.322715
# 3       Switzerland             4  ...                   0.367007           2.276716
# 4           Finland             5  ...                   0.382612           2.430182
#
# [5 rows x 12 columns]

# %%
data2017_final=data2017[['Overall rank', 'Country or region', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy','Freedom to make life choices', 'Generosity', 'Perceptions of corruption']]

# %%
data2017_final.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1            Norway  ...    0.362012                   0.315964
# 1             2           Denmark  ...    0.355280                   0.400770
# 2             3           Iceland  ...    0.475540                   0.153527
# 3             4       Switzerland  ...    0.290549                   0.367007
# 4             5           Finland  ...    0.245483                   0.382612
#
# [5 rows x 9 columns]

# %%
data2016.columns.values
# Out:
# array(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'], dtype=object)

# %%
data2016.rename(columns={'Country': 'Country or region', 'Happiness Rank': 'Overall rank', 'Happiness Score': 'Score', 
                         'Economy (GDP per Capita)': 'GDP per capita', 'Family': 'Social support', 'Freedom': 'Freedom to make life choices',
                         'Trust (Government Corruption)': 'Perceptions of corruption', 'Health (Life Expectancy)': 'Healthy life expectancy'}, inplace=True)

# %%
data2016.head()
# Out:
#   Country or region          Region  ...  Generosity  Dystopia Residual
# 0           Denmark  Western Europe  ...     0.36171            2.73939
# 1       Switzerland  Western Europe  ...     0.28083            2.69463
# 2           Iceland  Western Europe  ...     0.47678            2.83137
# 3            Norway  Western Europe  ...     0.37895            2.66465
# 4           Finland  Western Europe  ...     0.25492            2.82596
#
# [5 rows x 13 columns]

# %%
data2016_final=data2016[['Overall rank', 'Country or region', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy','Freedom to make life choices', 'Generosity', 'Perceptions of corruption']]

# %%
data2015.columns.values
# Out:
# array(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual'],
#       dtype=object)

# %%
data2015.rename(columns={'Country': 'Country or region', 'Happiness Rank': 'Overall rank', 'Happiness Score': 'Score', 
                         'Economy (GDP per Capita)': 'GDP per capita', 'Family': 'Social support', 'Freedom': 'Freedom to make life choices',
                         'Trust (Government Corruption)': 'Perceptions of corruption', 'Health (Life Expectancy)': 'Healthy life expectancy'}, inplace=True)

# %%
data2015_final=data2015[['Overall rank', 'Country or region', 'Score', 'GDP per capita', 'Social support', 'Healthy life expectancy','Freedom to make life choices', 'Generosity', 'Perceptions of corruption']]

# %%
data2019.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %%
data2018.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.202                      0.393
# 1             2            Norway  ...       0.286                      0.340
# 2             3           Denmark  ...       0.284                      0.408
# 3             4           Iceland  ...       0.353                      0.138
# 4             5       Switzerland  ...       0.256                      0.357
#
# [5 rows x 9 columns]

# %%
data2017_final.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1            Norway  ...    0.362012                   0.315964
# 1             2           Denmark  ...    0.355280                   0.400770
# 2             3           Iceland  ...    0.475540                   0.153527
# 3             4       Switzerland  ...    0.290549                   0.367007
# 4             5           Finland  ...    0.245483                   0.382612
#
# [5 rows x 9 columns]

# %%
data2016_final.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Denmark  ...     0.36171                    0.44453
# 1             2       Switzerland  ...     0.28083                    0.41203
# 2             3           Iceland  ...     0.47678                    0.14975
# 3             4            Norway  ...     0.37895                    0.35776
# 4             5           Finland  ...     0.25492                    0.41004
#
# [5 rows x 9 columns]

# %%
data2015_final.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1       Switzerland  ...     0.29678                    0.41978
# 1             2           Iceland  ...     0.43630                    0.14145
# 2             3           Denmark  ...     0.34139                    0.48357
# 3             4            Norway  ...     0.34699                    0.36503
# 4             5            Canada  ...     0.45811                    0.32957
#
# [5 rows x 9 columns]

# %%
dataFelicidad= pd.concat([data2019,data2018,data2017_final,data2016_final,data2015_final], ignore_index=True)

# %%
dataFelicidad.head()
# Out:
#    Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 0             1           Finland  ...       0.153                      0.393
# 1             2           Denmark  ...       0.252                      0.410
# 2             3            Norway  ...       0.271                      0.341
# 3             4           Iceland  ...       0.354                      0.118
# 4             5       Netherlands  ...       0.322                      0.298
#
# [5 rows x 9 columns]

# %%
#Estadísticas del dataset
dataFelicidad.describe()
# Out:
#        Overall rank       Score  ...  Generosity  Perceptions of corruption
# count    782.000000  782.000000  ...  782.000000                 781.000000
# mean      78.698210    5.379018  ...    0.218576                   0.125436
# std       45.182384    1.127456  ...    0.122321                   0.105816
# min        1.000000    2.693000  ...    0.000000                   0.000000
# 25%       40.000000    4.509750  ...    0.130000                   0.054000
# 50%       79.000000    5.322000  ...    0.201982                   0.091000
# 75%      118.000000    6.189500  ...    0.278832                   0.156030
# max      158.000000    7.769000  ...    0.838075                   0.551910
#
# [8 rows x 8 columns]

# %%
#Matriz de correlación
dataFelicidad.corr()
# Out:
#                               Overall rank  ...  Perceptions of corruption
# Overall rank                      1.000000  ...                  -0.372781
# Score                            -0.992066  ...                   0.398418
# GDP per capita                   -0.794791  ...                   0.306307
# Social support                   -0.644842  ...                   0.126401
# Healthy life expectancy          -0.743655  ...                   0.250512
# Freedom to make life choices     -0.537942  ...                   0.459593
# Generosity                       -0.117713  ...                   0.318920
# Perceptions of corruption        -0.372781  ...                   1.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# ## Visualizaciones rápidas

# %%
sb.pairplot(dataFelicidad, kind="reg")

# %%
#Histograma de todas las variables de mi dataset
dataFelicidad.hist(bins = 15, figsize=(20,15))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
figure, axs = plt.subplots(2,2, sharey=True, sharex=False, figsize=(8,8))
dataFelicidad.plot(kind="scatter", x="GDP per capita", y ="Score", ax=axs[0][0])
dataFelicidad.plot(kind="scatter", x="Freedom to make life choices", y="Score", ax=axs[0][1])
dataFelicidad.plot(kind="scatter", x="Social support", y ="Score", ax=axs[1][0])
dataFelicidad.plot(kind="scatter", x="Healthy life expectancy", y="Score", ax=axs[1][1])

# %%
dataFelicidad['Score'].hist(bins = 15, figsize=(10,7))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# ##Del cuadro anterior podemos observar que valores menores a 4 No son Felices, y valores mayores a 6 son Felices, y entre 4 y 6 podemos determinar que son Normales.
#
# ##### P25=4.5
# ##### P75=6.1
#
# * (3) Nivel de Felicidad Alto : Score > 6.1
# * (2) Nivel de Felicidad Medio : 4.5 < Score < 6.1
# * (1) Nivel de Felicidad Bajo : Score < 4.5

# %%
dataFelicidad["Nota"] = np.where(dataFelicidad["Score"]>=6.2, 3, np.where(dataFelicidad["Score"]<=4.5, 1, 2))

# %%
dataFelicidad["Nota"].unique()
# Out:
# array([3, 2, 1])

# %%
dataFelicidad.head()
# Out:
#    Overall rank Country or region  ...  Perceptions of corruption  Nota
# 0             1           Finland  ...                      0.393     3
# 1             2           Denmark  ...                      0.410     3
# 2             3            Norway  ...                      0.341     3
# 3             4           Iceland  ...                      0.118     3
# 4             5       Netherlands  ...                      0.298     3
#
# [5 rows x 10 columns]

# %%
#plt.matshow(data2019.corr())
dataFelicidad_corr = dataFelicidad.corr()
sb.heatmap(dataFelicidad_corr,
          xticklabels = dataFelicidad_corr.columns,
          yticklabels = dataFelicidad_corr.columns,
          cmap='coolwarm',
          annot=True)

# %% [markdown]
# # Prueba de Hipótesis

# %% [markdown]
# H0 = Los indicadores "PBI per cápita", "Expectativa de Vida Saludable", "Apoyo Social", y "Libertad para elegir" no influyen en los niveles de felicidad de un País.

# %% [markdown]
# H1 = Los indicadores "PBI per cápita", "Expectativa de Vida Saludable", "Apoyo Social", y "Libertad para elegir" Si influyen en los niveles de felicidad de un País.

# %% [markdown]
# # Probando varios Modelos

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report

# %%
Variables = ['GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices']
#Variables = ['GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Generosity','Perceptions of corruption']

# %%
X = dataFelicidad[Variables]
Y = dataFelicidad["Nota"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, random_state=0)
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Regresión Logistica

# %%
logit_model = LogisticRegression(max_iter=10000)
logit_model.fit(X_train,Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=10000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
logit_model.score(X_train,Y_train)
# Out:
# 0.7504

# %%
Pred_y_test = logit_model.predict(X_test)
Pred_y_test
# Out:
# array([3, 2, 2, 3, 2, 2, 2, 1, 3, 3, 2, 2, 1, 1, 3, 2, 1, 2, 2, 2, 3, 2,
#        2, 3, 3, 3, 2, 3, 1, 3, 2, 1, 2, 1, 3, 2, 1, 2, 2, 2, 1, 3, 2, 3,
#        3, 3, 2, 2, 2, 1, 2, 1, 3, 3, 1, 2, 2, 2, 1, 3, 3, 3, 2, 2, 2, 2,
#        2, 1, 1, 1, 2, 2, 2, 3, 3, 2, 2, 2, 2, 1, 3, 2, 2, 2, 1, 2, 1, 2,
#        2, 3, 3, 3, 2, 2, 2, 2, 2, 2, 3, 2, 1, 1, 2, 2, 3, 1, 3, 1, 1, 3,
#        1, 2, 2, 2, 2, 2, 3, 3, 3, 1, 3, 2, 2, 3, 1, 1, 2, 2, 1, 2, 2, 2,
#        1, 3, 2, 1, 3, 2, 2, 1, 2, 2, 2, 1, 3, 3, 3, 1, 2, 2, 3, 2, 2, 1,
#        2, 2, 1])

# %%
from sklearn import metrics
metrics.accuracy_score(Y_test,Pred_y_test)
# Out:
# 0.7388535031847133

# %%
print(classification_report(Y_test, Pred_y_test))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.64      0.68      0.66        34
#            2       0.78      0.72      0.75        86
#            3       0.74      0.84      0.78        37
#
#     accuracy                           0.74       157
#    macro avg       0.72      0.75      0.73       157
# weighted avg       0.74      0.74      0.74       157

# %% [markdown]
# #KNN

# %%
k_range = range(1, 20)
scores = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train, Y_train)
    scores.append(knn.score(X_test, Y_test))
plt.figure()
plt.xlabel('k')
plt.ylabel('accuracy')
plt.scatter(k_range, scores)
plt.xticks([0,5,10,15,20])
# Out:
# ([<matplotlib.axis.XTick at 0x7f68ed1a4ba8>,
# ...
#  <a list of 5 Text major ticklabel objects>)

# %%
scores
# Out:
# [0.7070063694267515,
#  0.7006369426751592,
#  0.7197452229299363,
#  0.7515923566878981,
#  0.7261146496815286,
#  0.7133757961783439,
#  0.7133757961783439,
#  0.7070063694267515,
#  0.7006369426751592,
#  0.7070063694267515,
#  0.6878980891719745,
#  0.7006369426751592,
#  0.6942675159235668,
#  0.7006369426751592,
#  0.7133757961783439,
#  0.7006369426751592,
#  0.7133757961783439,
#  0.7261146496815286,
#  0.732484076433121]

# %%
n_neighbors = 4

knn = KNeighborsClassifier(n_neighbors)
knn.fit(X_train, Y_train)
print('Accuracy of K-NN classifier on training set: {:.2f}'
     .format(knn.score(X_train, Y_train)))
print('Accuracy of K-NN classifier on test set: {:.4f}'
     .format(knn.score(X_test, Y_test)))
# Out:
# Accuracy of K-NN classifier on training set: 0.83
# Accuracy of K-NN classifier on test set: 0.7516

# %%
from sklearn.metrics import confusion_matrix
pred = knn.predict(X_test)
print(confusion_matrix(Y_test, pred))
print(classification_report(Y_test, pred))
# Out:
# [[27  7  0]
#  [16 60 10]
#  [ 0  6 31]]
#               precision    recall  f1-score   support
#
#            1       0.63      0.79      0.70        34
#            2       0.82      0.70      0.75        86
#            3       0.76      0.84      0.79        37
#
#     accuracy                           0.75       157
#    macro avg       0.74      0.78      0.75       157
# weighted avg       0.76      0.75      0.75       157

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
from sklearn.decomposition import PCA as RandomizedPCA
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report

# %%
pca = RandomizedPCA(whiten=True, random_state=42)
svc = SVC(kernel="rbf", class_weight="balanced")
model = make_pipeline(pca, svc)

# %%
param_grid = {
    "svc__C":[0.1,1,5,10,50],
    "svc__gamma":[0.0001, 0.0005, 0.001, 0.005, 0.01]
}
grid = GridSearchCV(model, param_grid)

# %time grid.fit(X_train, Y_train)
# Out:
# CPU times: user 2.03 s, sys: 2.42 ms, total: 2.03 s
# Wall time: 2.07 s
# GridSearchCV(cv=None, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('pca',
#                                         PCA(copy=True, iterated_power='auto',
#                                             n_components=None, random_state=42,
#                                             svd_solver='auto', tol=0.0,
#                                             whiten=True)),
#                                        ('svc',
#                                         SVC(C=1.0, break_ties=False,
#                                             cache_size=200,
#                                             class_weight='balanced', coef0=0.0,
#                                             decision_function_shape='ovr',
#                                             degree=3, gamma='scale',
#                                             kernel='rbf', max_iter=-1,
# ...

# %%
print(grid.best_params_)
# Out:
# {'svc__C': 50, 'svc__gamma': 0.01}

# %%
clasificador = grid.best_estimator_
ypred = clasificador.predict(X_test)

# %%
print(classification_report(Y_test, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.64      0.79      0.71        34
#            2       0.83      0.64      0.72        86
#            3       0.67      0.89      0.77        37
#
#     accuracy                           0.73       157
#    macro avg       0.72      0.78      0.73       157
# weighted avg       0.75      0.73      0.73       157

# %%
metrics.accuracy_score(Y_test,ypred)
# Out:
# 0.732484076433121

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree = DecisionTreeClassifier(criterion="entropy", min_samples_split=10, random_state=99)

# %%
tree.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=99, splitter='best')

# %%
ypredTree = tree.predict(X_test)

# %%
metrics.accuracy_score(Y_test,ypredTree)
# Out:
# 0.7261146496815286

# %%
print(classification_report(Y_test, ypredTree))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.66      0.68      0.67        34
#            2       0.79      0.69      0.73        86
#            3       0.68      0.86      0.76        37
#
#     accuracy                           0.73       157
#    macro avg       0.71      0.74      0.72       157
# weighted avg       0.73      0.73      0.73       157

# %% [markdown]
# # RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest = RandomForestClassifier(n_jobs=2, oob_score=True, n_estimators=100)
forest.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=2,
#                        oob_score=True, random_state=None, verbose=0,
#                        warm_start=False)

# %%
forest.oob_score_
# Out:
# 0.7344

# %%
ypredForest = forest.predict(X_test)

# %%
metrics.accuracy_score(Y_test,ypredForest)
# Out:
# 0.7643312101910829

# %%
print(classification_report(Y_test, ypredForest))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.67      0.76      0.71        34
#            2       0.82      0.73      0.77        86
#            3       0.76      0.84      0.79        37
#
#     accuracy                           0.76       157
#    macro avg       0.75      0.78      0.76       157
# weighted avg       0.77      0.76      0.77       157

# %% [markdown]
# # GBoosting

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, auc 
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score

# %%
clf = GradientBoostingClassifier(n_estimators=150, max_depth = 7, learning_rate = .4)
clf.fit(X_train, Y_train)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.4, loss='deviance', max_depth=7,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=150,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=None, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
ypredGboost = clf.predict(X_test)

# %%
metrics.accuracy_score(Y_test,ypredGboost)
# Out:
# 0.7515923566878981

# %%
print(classification_report(Y_test, ypredGboost))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.66      0.68      0.67        34
#            2       0.80      0.73      0.76        86
#            3       0.74      0.86      0.80        37
#
#     accuracy                           0.75       157
#    macro avg       0.73      0.76      0.74       157
# weighted avg       0.75      0.75      0.75       157

# %% [markdown]
# #Predicción con RandomForest

# %%
# Ecuador
X_val = [[0.912,1.312,0.868,0.498]]
X_val = scaler.transform(X_val)

# %%
SalidaPron = forest.predict(X_val)
SalidaPron
# Out:
# array([2])

# %%
# Sudan del Sur
X_val1 =[[0.306,0.575,0.295,0.01]]
X_val1 = scaler.transform(X_val1)

# %%
SalidaPron1 = forest.predict(X_val1)
SalidaPron1
# Out:
# array([1])

# %%
#Irlanda
X_val2 =[[1.499,1.553,0.999,0.516]]
X_val2 = scaler.transform(X_val2)

# %%
SalidaPron2 = forest.predict(X_val2)
SalidaPron2
# Out:
# array([3])

# %%
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt  
import seaborn as sns  
# roc curve and auc score
from sklearn.metrics import roc_curve  
from sklearn.metrics import roc_auc_score  
import sklearn.metrics as metrics

# %%
def plot_roc_curve(fpr, tpr):  
    plt.plot(fpr, tpr, color='orange', label='ROC')
    plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic (ROC) Curve')
    plt.legend()
    plt.show()

# %%
probs1 = logit_model.predict_proba(X_test)
preds1 = probs1[:, 1]

# %%
#auc = roc_auc_score(Y_test, probs1)  
#print('AUC: %.2f' % auc)  

fpr, tpr, threshold = metrics.roc_curve(Y_test, preds1)
roc_auc = metrics.auc(fpr, tpr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-be4f3cfe142b> in <module>()
#       2 #print('AUC: %.2f' % auc)
#       3
# ----> 4 fpr, tpr, threshold = metrics.roc_curve(Y_test, preds1)
#       5 roc_auc = metrics.auc(fpr, tpr)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     769     """
#     770     fps, tps, thresholds = _binary_clf_curve(
# --> 771         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     772
#     773     # Attempt to drop thresholds corresponding to points in between and
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     534     if not (y_type == "binary" or
# ...
